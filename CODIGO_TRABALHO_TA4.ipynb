# %% [markdown]
# ## IMPORTAÇÃO DATASET IRIS
#
#
# ```

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import math
import statistics
import matplotlib.pyplot as plt
from scipy import stats
csv_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
col_names = ['Sepal_Length','Sepal_Width','Petal_Length','Petal_Width','Class']
dataset =  pd.read_csv(csv_url, names = col_names)
dataset.shape
dataset
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width           Class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
media = dataset['Sepal_Length'].mean() 
print("Média ", media)
# Out:
# Média  5.843333333333334

# %% [markdown]
# ##  MEDIDAS DE POSIÇÃO E DISPERSÃO

# %% [markdown]
# Média

# %%
media = dataset.mean() 
dataset_media=pd.DataFrame(media)
dataset_media
# Out:
# <ipython-input-75-0109a11753d3>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   media = dataset.mean()
#                      0
# Sepal_Length  5.843333
# Sepal_Width   3.054000
# Petal_Length  3.758667
# Petal_Width   1.198667

# %%
mediana = dataset.median() 
dataset_mediana=pd.DataFrame(mediana)
dataset_mediana
# Out:
# <ipython-input-76-d6b9d4c046e5>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mediana = dataset.median()
#                  0
# Sepal_Length  5.80
# Sepal_Width   3.00
# Petal_Length  4.35
# Petal_Width   1.30

# %%
dados={'Sepal_Length_moda':[statistics.mode(dataset['Sepal_Length'])],
       'Sepal_Width_moda':[statistics.mode(dataset['Sepal_Width'])],
       'Petal_Length_moda':[statistics.mode(dataset['Petal_Length'])],
       'Petal_Width_moda':[statistics.mode(dataset['Petal_Width'])]
        }
dataset_moda=pd.DataFrame(dados)
dataset_moda
# Out:
#    Sepal_Length_moda  Sepal_Width_moda  Petal_Length_moda  Petal_Width_moda
# 0                5.0               3.0                1.5               0.2

# %%
desvio_padrao = np.std(dataset)
dataset_desvio=pd.DataFrame(desvio_padrao)
dataset_desvio
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3613: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
#                      0
# Sepal_Length  0.825301
# Sepal_Width   0.432147
# Petal_Length  1.758529
# Petal_Width   0.760613

# %%
dataset_petal_lenght=dataset[['Petal_Length','Class']]
frenquence_petal_length_setosa=dataset_petal_lenght[dataset_petal_lenght['Class']=='Iris-setosa']
frenquence_petal_length_setosa=pd.DataFrame(frenquence_petal_length_setosa)
freq_setosa=frenquence_petal_length_setosa.groupby('Class').value_counts()
freq_setosa=pd.DataFrame(freq_setosa)
df_ordenado_iris_setosa = freq_setosa.sort_values(by='Petal_Length')
df_ordenado_iris_setosa
# Out:
#                            0
# Class       Petal_Length
# Iris-setosa 1.0            1
#             1.1            1
#             1.2            2
#             1.3            7
#             1.4           12
#             1.5           14
#             1.6            7
#             1.7            4
#             1.9            2

# %%
frenquence_petal_length_versicolor=dataset_petal_lenght[dataset_petal_lenght['Class']=='Iris-versicolor']
frenquence_petal_lengtfrenquence_petal_length_versicolorh_versicolor=pd.DataFrame(frenquence_petal_length_versicolor)
freq_versicilor=frenquence_petal_length_versicolor.groupby('Class').value_counts()
freq_versicilor=pd.DataFrame(freq_versicilor)
df_ordenado_verisicolor = freq_versicilor.sort_values(by='Petal_Length')
df_ordenado_verisicolor
# Out:
#                               0
# Class           Petal_Length
# Iris-versicolor 3.0           1
#                 3.3           2
#                 3.5           2
#                 3.6           1
#                 3.7           1
#                 3.8           1
#                 3.9           3
#                 4.0           5
#                 4.1           3
#                 4.2           4
#                 4.3           2
#                 4.4           4
#                 4.5           7
#                 4.6           3
#                 4.7           5
#                 4.8           2
#                 4.9           2
#                 5.0           1
#                 5.1           1

# %%
frenquence_petal_length_versicolor=dataset_petal_lenght[dataset_petal_lenght['Class']=='Iris-virginica']
frenquence_petal_lengtfrenquence_petal_length_versicolorh_versicolor=pd.DataFrame(frenquence_petal_length_versicolor)
freq_versicilor=frenquence_petal_length_versicolor.groupby('Class').value_counts()
freq_versicilor=pd.DataFrame(freq_versicilor)
df_ordenado_verisicolor = freq_versicilor.sort_values(by='Petal_Length')
df_ordenado_verisicolor
# Out:
#                              0
# Class          Petal_Length
# Iris-virginica 4.5           1
#                4.8           2
#                4.9           3
#                5.0           3
#                5.1           7
#                5.2           2
#                5.3           2
#                5.4           2
#                5.5           3
#                5.6           6
#                5.7           3
#                5.8           3
#                5.9           2
#                6.0           2
#                6.1           3
#                6.3           1
#                6.4           1
#                6.6           1
#                6.7           2
#                6.9           1

# %%
dataset_setal_lenght=dataset[['Sepal_Length','Class']]
frenquence_setal_length_setosa=dataset_setal_lenght[dataset_setal_lenght['Class']=='Iris-setosa']
frenquence_setal_length_setosa=pd.DataFrame(frenquence_setal_length_setosa)
freq_setosa=frenquence_setal_length_setosa.groupby('Class').value_counts()
freq_setosa=pd.DataFrame(freq_setosa)
df_ordenado_iris_setosa = freq_setosa.sort_values(by='Sepal_Length')
df_ordenado_iris_setosa
# Out:
#                           0
# Class       Sepal_Length
# Iris-setosa 4.3           1
#             4.4           3
#             4.5           1
#             4.6           4
#             4.7           2
#             4.8           5
#             4.9           4
#             5.0           8
#             5.1           8
#             5.2           3
#             5.3           1
#             5.4           5
#             5.5           2
#             5.7           2
#             5.8           1

# %%
dataset_setal_lenght=dataset[['Sepal_Length','Class']]
frenquence_setal_length_setosa=dataset_setal_lenght[dataset_setal_lenght['Class']=='Iris-versicolor']
frenquence_setal_length_setosa=pd.DataFrame(frenquence_setal_length_setosa)
freq_versicolor=frenquence_setal_length_setosa.groupby('Class').value_counts()
freq_versicolor=pd.DataFrame(freq_setosa)
df_ordenado_iris_versicolor = freq_versicolor.sort_values(by='Sepal_Length')
df_ordenado_iris_versicolor
# Out:
#                           0
# Class       Sepal_Length
# Iris-setosa 4.3           1
#             4.4           3
#             4.5           1
#             4.6           4
#             4.7           2
#             4.8           5
#             4.9           4
#             5.0           8
#             5.1           8
#             5.2           3
#             5.3           1
#             5.4           5
#             5.5           2
#             5.7           2
#             5.8           1

# %%
dataset_setal_lenght=dataset[['Sepal_Length','Class']]
frenquence_setal_length_virginica=dataset_setal_lenght[dataset_setal_lenght['Class']=='Iris-virginica']
frenquence_setal_length_virginica=pd.DataFrame(frenquence_setal_length_virginica)
freq_virginica=frenquence_setal_length_virginica.groupby('Class').value_counts()
freq_virginica=pd.DataFrame(freq_virginica)
df_ordenado_iris_virginica = freq_virginica.sort_values(by='Sepal_Length')
df_ordenado_iris_virginica
# Out:
#                              0
# Class          Sepal_Length
# Iris-virginica 4.9           1
#                5.6           1
#                5.7           1
#                5.8           3
#                5.9           1
#                6.0           2
#                6.1           2
#                6.2           2
#                6.3           6
#                6.4           5
#                6.5           4
#                6.7           5
#                6.8           2
#                6.9           3
#                7.1           1
#                7.2           3
#                7.3           1
#                7.4           1
#                7.6           1
#                7.7           4
#                7.9           1

# %%
dataset[['Sepal_Length','Petal_Length']].corr()
# Out:
#               Sepal_Length  Petal_Length
# Sepal_Length      1.000000      0.871754
# Petal_Length      0.871754      1.000000

# %%
dataset[['Sepal_Width','Petal_Width']].corr()
# Out:
#              Sepal_Width  Petal_Width
# Sepal_Width     1.000000    -0.356544
# Petal_Width    -0.356544     1.000000

# %%
#Gráfico de dispersão
sns.relplot(x='Petal_Width', y='Sepal_Width', data=dataset,hue='Class')

# %%
#Gráfico de dispersão
sns.relplot(x='Sepal_Length', y='Petal_Length', data=dataset,hue='Class')

# %%
sns.lmplot(x='Petal_Length', y="Petal_Width",hue='Class' , data=dataset)

# %%
sns.lmplot(x='Sepal_Length', y="Sepal_Width",hue='Class' , data=dataset)

# %%
sns.boxplot(dataset)
# Out:
# <Axes: >

# %%
valor_minimo=np.min(dataset['Sepal_Length'])
valor_maximo=np.max(dataset['Sepal_Length'])
print(valor_minimo)
print(valor_maximo)
intevalos=np.arange(valor_minimo,valor_maximo, step=1)
intevalos
intervalo1, intervalo2, intervalo3,intervalo4=0,0,0,0
for i in range(len(dataset['Sepal_Length'])):
  if dataset['Sepal_Length'][i]>intevalos[0] and dataset['Sepal_Length'][i]<intevalos[1]:
    intervalo1+=1
  elif dataset['Sepal_Length'][i]>intevalos[1] and dataset['Sepal_Length'][i]<intevalos[2]:
    intervalo2+=1
  elif dataset['Sepal_Length'][i]>intevalos[2] and dataset['Sepal_Length'][i]<intevalos[3]:
    intervalo3+=1
lista_intervalo=[]
lista_intervalo.append(intervalo1)
lista_intervalo.append(intervalo2)
lista_intervalo.append(intervalo3)
lista_intervalo
classes=[]
for i in range(len(lista_intervalo)):
  classes.append(str(intevalos[i])+'-'+str(intevalos[i+1]))
classes
plt.bar(classes,lista_intervalo)
plt.title('Sepal_Length - distribuição de frequência-histograma')
plt.xlabel('Intervalos - Sepal_Length')
plt.ylabel('Valores')
# Out:
# 4.3
# 7.9
# Text(0, 0.5, 'Valores')

# %%
valor_minimo=np.min(dataset['Petal_Length'])
valor_maximo=np.max(dataset['Petal_Length'])
print(valor_minimo)
print(valor_maximo)
intevalos=np.arange(valor_minimo,valor_maximo, step=1)
intevalos
intervalo1, intervalo2, intervalo3,intervalo4=0,0,0,0
for i in range(len(dataset['Petal_Length'])):
  if dataset['Petal_Length'][i]>=intevalos[0] and dataset['Petal_Length'][i]<intevalos[1]:
    intervalo1+=1
  elif dataset['Petal_Length'][i]>=intevalos[1] and dataset['Petal_Length'][i]<intevalos[2]:
    intervalo2+=1
  elif dataset['Petal_Length'][i]>=intevalos[2] and dataset['Petal_Length'][i]<intevalos[3]:
    intervalo3+=1
lista_intervalo=[]
lista_intervalo.append(intervalo1)
lista_intervalo.append(intervalo2)
lista_intervalo.append(intervalo3)
lista_intervalo
classes=[]
for i in range(len(lista_intervalo)):
  classes.append(str(intevalos[i])+'-'+str(intevalos[i+1]))
classes
plt.bar(classes,lista_intervalo)
plt.title('Petal_Length - distribuição de frequência-histograma')
plt.xlabel('Intervalos - Petal_Length')
plt.ylabel('Valores')
# Out:
# 1.0
# 6.9
# Text(0, 0.5, 'Valores')

# %%
valor_minimo=np.min(dataset['Sepal_Width'])
valor_maximo=np.max(dataset['Sepal_Width'])
print(valor_minimo)
print(valor_maximo)
intevalos=np.arange(valor_minimo,valor_maximo, step=1)
intevalos
intervalo1, intervalo2, intervalo3,intervalo4=0,0,0,0
for i in range(len(dataset['Sepal_Width'])):
  if dataset['Sepal_Width'][i]>=intevalos[0] and dataset['Sepal_Width'][i]<intevalos[1]:
    intervalo1+=1
  elif dataset['Sepal_Width'][i]>=intevalos[1] and dataset['Sepal_Width'][i]<intevalos[2]:
    intervalo2+=1
  #elif dataset['Sepal_Width'][i]>=intevalos[2] and dataset['Sepal_Width'][i]<intevalos[3]:
    #intervalo3+=1
lista_intervalo=[]
lista_intervalo.append(intervalo1)
lista_intervalo.append(intervalo2)
lista_intervalo
classes=[]
for i in range(len(lista_intervalo)):
  classes.append(str(intevalos[i])+'-'+str(intevalos[i+1]))
classes
plt.bar(classes,lista_intervalo)
plt.title('Sepal_Width - distribuição de frequência-histograma')
plt.xlabel('Intervalos - Sepal_Width')
plt.ylabel('Valores')
# Out:
# 2.0
# 4.4
# Text(0, 0.5, 'Valores')

# %%
valor_minimo=np.min(dataset['Petal_Width'])
valor_maximo=np.max(dataset['Petal_Width'])
print(valor_minimo)
print(valor_maximo)
intevalos=np.arange(valor_minimo,valor_maximo, step=1)
intevalos
intervalo1, intervalo2, intervalo3,intervalo4=0,0,0,0
for i in range(len(dataset['Petal_Width'])):
  if dataset['Petal_Width'][i]>=intevalos[0] and dataset['Petal_Width'][i]<intevalos[1]:
    intervalo1+=1
  elif dataset['Petal_Width'][i]>=intevalos[1] and dataset['Petal_Width'][i]<intevalos[2]:
    intervalo2+=1
  #elif dataset['Sepal_Width'][i]>=intevalos[2] and dataset['Sepal_Width'][i]<intevalos[3]:
    #intervalo3+=1
lista_intervalo=[]
lista_intervalo.append(intervalo1)
lista_intervalo.append(intervalo2)
lista_intervalo
classes=[]
for i in range(len(lista_intervalo)):
  classes.append(str(intevalos[i])+'-'+str(intevalos[i+1]))
classes
plt.bar(classes,lista_intervalo)
plt.title('Petal_Width - distribuição de frequência-histograma')
plt.xlabel('Intervalos - Petal_Width')
plt.ylabel('Valores')
# Out:
# 0.1
# 2.5
# Text(0, 0.5, 'Valores')

# %%
#Gráfico de dispersão
sns.relplot(x='Sepal_Length', y='Sepal_Width', data=dataset,hue='Class')

# %%
sns.relplot(x='Petal_Length', y='Sepal_Length', data=dataset, hue='Class')

# %%
sns.catplot(x='Petal_Width', y='Sepal_Width', hue='Class',kind='bar', data=dataset)

# %%
sns.lmplot(x='Petal_Length', y="Sepal_Length",hue='Class' , data=dataset)

# %%
#Gráfico de dispersão
sns.relplot(x=dataset['Petal_Length'], y=dataset['Sepal_Length'],data=dataset,hue='Class')

# %%
sns.barplot(x='Class', y="Sepal_Length",  data=dataset)
# Out:
# <Axes: xlabel='Class', ylabel='Sepal_Length'>

# %%
sns.barplot(x='Class', y="Petal_Width",  data=dataset, hue='Class')
# Out:
# <Axes: xlabel='Class', ylabel='Petal_Width'>

# %%
sns.barplot(x='Class', y="Sepal_Width",  data=dataset)
# Out:
# <Axes: xlabel='Class', ylabel='Sepal_Width'>

# %%
sns.barplot(x='Class', y="Petal_Length",  data=dataset)
# Out:
# <Axes: xlabel='Class', ylabel='Petal_Length'>

# %%
sns.boxplot(dataset)
# Out:
# <Axes: >

# %%
sns.catplot(x='Sepal_Width',y='Petal_Width',data=dataset, hue='Class')

# %%
sns.catplot(x='Petal_Width',y='Sepal_Width',data=dataset.query('Petal_Length<5'), hue='Class')

# %%
g=sns.FacetGrid(dataset,col='Class', hue='Petal_Width')
g.map(sns.scatterplot,'Petal_Width','Petal_Width')

# %%
g=sns.FacetGrid(dataset,col='Class')
g.map(sns.scatterplot,'Petal_Length','Petal_Length')

# %%
g=sns.FacetGrid(dataset,col='Class')
g.map(sns.histplot,'Sepal_Length')

# %%
g=sns.FacetGrid(dataset,col='Class')
g.map(sns.histplot,'Sepal_Width')

# %%
g=sns.PairGrid(dataset)
g.map(sns.scatterplot)

# %%
sns.distplot(dataset['Sepal_Width']);
# Out:
# <ipython-input-31-f3b85bce63e5>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['Sepal_Width']);

# %%
#média agrupada por classe
dataset.groupby('Class').mean()
# Out:
#                  Sepal_Length  Sepal_Width  Petal_Length  Petal_Width
# Class
# Iris-setosa             5.006        3.418         1.464        0.244
# Iris-versicolor         5.936        2.770         4.260        1.326
# Iris-virginica          6.588        2.974         5.552        2.026

# %%
#Existe uma correção entre o comprimento as petálas e o comprimento das sépalas
dataset[['Sepal_Length','Petal_Length']].corr()
# Out:
#               Sepal_Length  Petal_Length
# Sepal_Length      1.000000      0.871754
# Petal_Length      0.871754      1.000000

# %%
dataset[['Sepal_Width','Petal_Width']].corr()
# Out:
#              Sepal_Width  Petal_Width
# Sepal_Width     1.000000    -0.356544
# Petal_Width    -0.356544     1.000000

# %%
dataset.head()
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width        Class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# ## Padronização (z-score) e k-NN

# %%
import pandas as pd
import numpy as np
dataset.dropna(inplace=True)
dataset.head()
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width        Class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# ### Sem padronização

# %%
X = dataset.iloc[:, 1:4].values
X
# Out:
# array([[3.5, 1.4, 0.2],
#        [3. , 1.4, 0.2],
#        [3.2, 1.3, 0.2],
#        [3.1, 1.5, 0.2],
#        [3.6, 1.4, 0.2],
#        [3.9, 1.7, 0.4],
#        [3.4, 1.4, 0.3],
#        [3.4, 1.5, 0.2],
#        [2.9, 1.4, 0.2],
#        [3.1, 1.5, 0.1],
#        [3.7, 1.5, 0.2],
#        [3.4, 1.6, 0.2],
#        [3. , 1.4, 0.1],
#        [3. , 1.1, 0.1],
#        [4. , 1.2, 0.2],
#        [4.4, 1.5, 0.4],
#        [3.9, 1.3, 0.4],
#        [3.5, 1.4, 0.3],
#        [3.8, 1.7, 0.3],
#        [3.8, 1.5, 0.3],
#        [3.4, 1.7, 0.2],
#        [3.7, 1.5, 0.4],
#        [3.6, 1. , 0.2],
#        [3.3, 1.7, 0.5],
#        [3.4, 1.9, 0.2],
#        [3. , 1.6, 0.2],
#        [3.4, 1.6, 0.4],
#        [3.5, 1.5, 0.2],
#        [3.4, 1.4, 0.2],
#        [3.2, 1.6, 0.2],
#        [3.1, 1.6, 0.2],
#        [3.4, 1.5, 0.4],
#        [4.1, 1.5, 0.1],
#        [4.2, 1.4, 0.2],
#        [3.1, 1.5, 0.1],
#        [3.2, 1.2, 0.2],
#        [3.5, 1.3, 0.2],
#        [3.1, 1.5, 0.1],
# ...

# %%
y = dataset['Class'].values
y
# Out:
# array(['Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
X_treinamento, X_teste, y_treinamento, y_teste = train_test_split(X, y, test_size = 0.2,
                                                                  stratify = y)

# %%
np.mean(X_treinamento[0]), np.median(X_treinamento[0]), np.std(X_treinamento[0])
# Out:
# (3.9, 3.0, 1.9442222095223578)

# %%
np.mean(X_teste[0]), np.median(X_teste[0]), np.std(X_teste[0])
# Out:
# (1.8333333333333333, 1.9, 1.307244770075172)

# %%
knn = KNeighborsClassifier()
knn.fit(X_treinamento, y_treinamento)
# Out:
# KNeighborsClassifier()

# %%
previsoes = knn.predict(X_teste)

# %%
accuracy_score(y_teste, previsoes)
# Out:
# 0.9333333333333333

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_teste,previsoes))
#print(confusion_matrix(,previsoX_testees.targets))
matriz_confusao = confusion_matrix(y_teste, previsoes)
targets=['Iris-setosa','Iris-versicolor','Iris-virginica']
print(classification_report(y_teste,previsoes, target_names=targets))
# Out:
# [[10  0  0]
#  [ 0 10  0]
#  [ 0  2  8]]
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        10
# Iris-versicolor       0.83      1.00      0.91        10
#  Iris-virginica       1.00      0.80      0.89        10
#
#        accuracy                           0.93        30
#       macro avg       0.94      0.93      0.93        30
#    weighted avg       0.94      0.93      0.93        30

# %% [markdown]
# ### Com padronização

# %%
from sklearn.preprocessing import StandardScaler

# %%
z_score_treinamento = StandardScaler()
z_score_teste = StandardScaler()

# %%
X_treinamento_p = z_score_treinamento.fit_transform(X_treinamento)
X_teste_p = z_score_teste.fit_transform(X_teste)

# %%
X_treinamento_p, X_teste_p
# Out:
# (array([[-0.14913102,  1.56981066,  1.17809909],
#         [-0.14913102, -1.50916418, -1.45452458],
#         [-0.14913102,  1.17794113,  1.17809909],
#         [-0.14913102,  0.61812752,  0.78320554],
#         [-0.61395497,  1.00999705,  1.17809909],
#         [ 0.54810491,  0.5061648 ,  0.51994317],
#         [-0.14913102,  0.17027664,  0.12504962],
#         [ 0.78051689, -1.22925738, -1.32289339],
#         [-0.61395497,  1.62579202,  1.04646791],
#         [-1.07877892, -0.16561153, -0.26984393],
#         [ 1.71016479,  1.45784793,  1.04646791],
#         [ 1.94257677, -1.17327602, -1.05963103],
#         [ 0.08328096, -1.28523874, -1.45452458],
#         [ 1.71016479, -1.22925738, -1.32289339],
#         [-1.07877892,  1.00999705,  0.25668081],
#         [-0.14913102,  0.95401569,  1.17809909],
#         [-0.38154299, -0.10963016,  0.12504962],
#         [-0.84636695,  0.73009025,  0.91483672],
#         [ 0.54810491,  1.06597841,  1.70462382],
# ...

# %%
min(X_treinamento_p[0]), max(X_treinamento_p[0])
# Out:
# (-0.1491310182933115, 1.5698106559567597)

# %%
np.mean(X_treinamento_p), np.median(X_treinamento_p), np.std(X_treinamento_p)
# Out:
# (2.8619082412559593e-16, 0.11967245109647498, 1.0)

# %%
np.mean(X_teste_p), np.median(X_teste_p), np.std(X_teste_p)
# Out:
# (-7.416906595065282e-16, 0.1658519148678906, 0.9999999999999998)

# %%
knn = KNeighborsClassifier()
knn.fit(X_treinamento_p, y_treinamento)
previsoes = knn.predict(X_teste_p)
accuracy_score(y_teste, previsoes)
# Out:
# 0.9666666666666667

# %%
matriz_confusao = confusion_matrix(y_teste, previsoes)
print(confusion_matrix(y_teste,previsoes))
targets=['Iris-setosa','Iris-versicolor','Iris-virginica']
print(classification_report(y_teste,previsoes, target_names=targets))
# Out:
# [[10  0  0]
#  [ 0 10  0]
#  [ 0  1  9]]
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        10
# Iris-versicolor       0.91      1.00      0.95        10
#  Iris-virginica       1.00      0.90      0.95        10
#
#        accuracy                           0.97        30
#       macro avg       0.97      0.97      0.97        30
#    weighted avg       0.97      0.97      0.97        30
